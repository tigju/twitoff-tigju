# %%
import pandas as pd
import numpy as np
import tweepy
import os

# %%
TWITTER_API_KEY = os.getenv("TWITTER_API_KEY")
TWITTER_API_SECRET = os.getenv("TWITTER_API_SECRET")
TWITTER_ACCESS_TOKEN = os.getenv("TWITTER_ACCESS_TOKEN")
TWITTER_ACCESS_TOKEN_SECRET = os.getenv("TWITTER_ACCESS_TOKEN_SECRET")

auth = tweepy.OAuthHandler(TWITTER_API_KEY, TWITTER_API_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
print("AUTH", type(auth))

api = tweepy.API(auth)
# Out:
# AUTH <class 'tweepy.auth.OAuthHandler'>

# %%
my_tweets = api.user_timeline("tigju24", tweet_mode="extended", count=150)
print(type(my_tweets))
# Out:
# <class 'tweepy.models.ResultSet'>

# %%
for tweet in my_tweets:
    print("---------")
    print(tweet.id, tweet.full_text, tweet.user.screen_name, tweet.user.name)
    break
# Out:
# ---------
# 1395847157207511045 View my verified achievement from @lambdaschool. https://t.co/FMetwYRtZK tigju24 Julia S.

# %%
bieber_tweets = api.user_timeline("justinbieber", tweet_mode="extended", count=150)
print(type(bieber_tweets))
# Out:
# <class 'tweepy.models.ResultSet'>

# %%
musk_tweets = api.user_timeline("elonmusk", tweet_mode="extended", count=150)
print(type(musk_tweets))
# Out:
# <class 'tweepy.models.ResultSet'>

# %%
doc1 = []
for t in bieber_tweets:
    doc1.append([t.id, t.full_text, t.user.screen_name, t.user.name])

# %%
doc2 = []
for t in musk_tweets:
    doc2.append([t.id, t.full_text, t.user.screen_name, t.user.name])

# %%
doc1
# Out:
# [[1396927212461375489,
#   'Justice World Tour 2022 presented by\xa0@tmobile on sale now https://t.co/AcBtIUse3H https://t.co/V4pHJ3z6kl',
#   'justinbieber',
#   'Justin Bieber'],
#  [1393239957939146755,
#   'RT @bieberfever: Pre-order #JUSTICE on vinyl https://t.co/vYq7oRm7w0 https://t.co/IJ4ac6q0QH',
#   'justinbieber',
#   'Justin Bieber'],
#  [1391853886512717828,
#   'Let it go video out right now\xa0@djkhaled\xa0@21savage \n\nVideo by\xa0@ColinTilley https://t.co/ZigEYOd72f https://t.co/yVLnG9y3fc',
#   'justinbieber',
#   'Justin Bieber'],
#  [1390384015358705664,
#   'Justice World Tour 2022 presented by\xa0@tmobile https://t.co/AcBtIUse3H https://t.co/eTvXJbNw6M',
#   'justinbieber',
#   'Justin Bieber'],
#  [1389662980703412233,
#   'https://t.co/I2HzVTGYm8',
#   'justinbieber',
#   'Justin Bieber'],
#  [1389293667823886338,
# ...

# %%
data = pd.DataFrame(data=doc1, columns=['id', 'full_text', 'screen_name', 'user'])

# %%
data1 = pd.DataFrame(data=doc2, columns=['id', 'full_text', 'screen_name', 'user'])

# %%
data.append(data1)
# Out:
#                       id                                          full_text  \
# 0    1396927212461375489  Justice World Tour 2022 presented by @tmobile ...
# 1    1393239957939146755  RT @bieberfever: Pre-order #JUSTICE on vinyl h...
# 2    1391853886512717828  Let it go video out right now @djkhaled @21sav...
# 3    1390384015358705664  Justice World Tour 2022 presented by @tmobile ...
# 4    1389662980703412233                            https://t.co/I2HzVTGYm8
# ..                   ...                                                ...
# 144  1367520455691821059  Hold On video tonight 🏍\nhttps://t.co/8ODJEqbn...
# 145  1367294001846640642  Call if you need somebody I will be there for ...
# 146  1367246273804263426                            https://t.co/RaCASOKN1y
# 147  1366433577961930754  Hold On. Friday https://t.co/6t1CEcUK46 https:...
# 148  1365691078209339394    https://t.co/bcThKNn8W4 https://t.co/NVoi1Lg4U3
#
#       screen_name           user
# ...

# %%
data.head(10)
# Out:
#                     id                                          full_text  \
# 0  1396927212461375489  Justice World Tour 2022 presented by @tmobile ...
# 1  1393239957939146755  RT @bieberfever: Pre-order #JUSTICE on vinyl h...
# 2  1391853886512717828  Let it go video out right now @djkhaled @21sav...
# 3  1390384015358705664  Justice World Tour 2022 presented by @tmobile ...
# 4  1389662980703412233                            https://t.co/I2HzVTGYm8
# 5  1389293667823886338  RT @djkhaled: Video coming #LETITGO @justinbie...
# 6  1389293394728570880                          🔥 https://t.co/yAqVNnn9An
# 7  1387069033485320192  RT @FallonTonight: .@JustinBieber, Jimmy &amp;...
# 8  1386829770336444417  RT @FallonTonight: TONIGHT: 👀🍑 https://t.co/zE...
# 9  1385398169001943046  Justice listening party starts now\nhttps://t....
#
#     screen_name           user
# 0  justinbieber  Justin Bieber
# 1  justinbieber  Justin Bieber
# 2  justinbieber  Justin Bieber
# ...

# %% [markdown]
# ### Basic text cleaning

# %%
import nltk

# %%
#nltk.download()

#python -m nltk.downloader all

# %% [markdown]
# #### 1. Convert to lower case

# %%
data['text_lower']  = data['full_text'].str.lower()
data['text_lower'].head(10)
# Out:
# 0    justice world tour 2022 presented by @tmobile ...
# 1    rt @bieberfever: pre-order #justice on vinyl h...
# 2    let it go video out right now @djkhaled @21sav...
# 3    justice world tour 2022 presented by @tmobile ...
# 4                              https://t.co/i2hzvtgym8
# 5    rt @djkhaled: video coming #letitgo @justinbie...
# 6                            🔥 https://t.co/yaqvnnn9an
# 7    rt @fallontonight: .@justinbieber, jimmy &amp;...
# 8    rt @fallontonight: tonight: 👀🍑 https://t.co/ze...
# 9    justice listening party starts now\nhttps://t....
# Name: text_lower, dtype: object

# %% [markdown]
# #### 2. remove hyperlinks from tweets

# %%
import re

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+', flags=re.MULTILINE)
    return url_pattern.sub(r'', text)

data['no_links_text'] = data['text_lower'].apply(remove_urls)

data['no_links_text'].head(10)
# Out:
# 0    justice world tour 2022 presented by @tmobile ...
# 1       rt @bieberfever: pre-order #justice on vinyl
# 2    let it go video out right now @djkhaled @21sav...
# 3      justice world tour 2022 presented by @tmobile
# 4
# 5    rt @djkhaled: video coming #letitgo @justinbie...
# 6                                                   🔥
# 7    rt @fallontonight: .@justinbieber, jimmy &amp;...
# 8                      rt @fallontonight: tonight: 👀🍑
# 9                justice listening party starts now\n
# Name: no_links_text, dtype: object

# %% [markdown]
# #### 3. Convert emojis and emoticons to words with emot library

# %%
from emot.emo_unicode import UNICODE_EMO, EMOTICONS

# %%
# text = '🔥'
# text2 = '👀🍑'
# for emot in UNICODE_EMO:
#     text = text.replace(emot, "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
#     text2 = text2.replace(emot, "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
    
# print(text.center(5))
# print(text2)

# %%
def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', " ".join(EMOTICONS[emot].replace(",","").split()), text)
    return text
    
def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = text.replace(emot, " ".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
    return text
    
data['covn_emot'] = data['no_links_text'].apply(convert_emoticons)
data['covn_emoji'] = data['covn_emot'].apply(convert_emojis)

data['covn_emoji'].head(20)
# Out:
# 0     justice world tour 2022 presented by @tmobile ...
# 1        rt @bieberfever: pre-order #justice on vinyl
# 2     let it go video out right now @djkhaled @21sav...
# 3       justice world tour 2022 presented by @tmobile
# 4
# 5     rt @djkhaleTongue sticking out cheeky playful ...
# 6                                                 fire
# 7     rt @fallontonight: .@justinbieber, jimmy &amp;...
# 8                rt @fallontonight: tonight: eyespeach
# 9                 justice listening party starts now\n
# 10    rt @facebook: celebrate #earthday with @billny...
# 11         justice listening party\ntomorrow 6pm pst\n
# 12    rt @bieberfever: submit your #peaches single a...
# 13    dont miss it in 15 minutes live from paris wit...
# 14    rt @youtube: got my peaches out in… paris peac...
# 15    come check out this live from paris experience...
# 16    rt @youtubemusic: got my peaches out in… paris...
# 17    rt @gqmagazine: presenting gq’s may cover star...
# ...

# %%
# separate emojis from text ex.: @djkhaleTongue -> @djkhale Tongue
def sep_emoji(text):
    new_text = re.sub('([A-Z])', r' \1', text)
    return new_text.lower()

data['covn_emoji'] = data['covn_emoji'].apply(sep_emoji)

data['covn_emoji'].head(10)
# Out:
# 0    justice world tour 2022 presented by @tmobile ...
# 1       rt @bieberfever: pre-order #justice on vinyl
# 2    let it go video out right now @djkhaled @21sav...
# 3      justice world tour 2022 presented by @tmobile
# 4
# 5    rt @djkhale tongue sticking out cheeky playful...
# 6                                                fire
# 7    rt @fallontonight: .@justinbieber, jimmy &amp;...
# 8               rt @fallontonight: tonight: eyespeach
# 9                justice listening party starts now\n
# Name: covn_emoji, dtype: object

# %% [markdown]
# #### 4. Normalize tweets abbreviations

# %%
# top twitter abbreviations source: https://www.socialmediatoday.com/content/top-twitter-abbreviations-you-need-know

tweets_abbr = {
    "EM": "Email Marketing",
    "EZine": "Electronic Magazine",
    "FB": "Facebook",
    "LI": "LinkedIn",
    "SEO": "Search Engine Optimization",
    "SM": "Social Media",
    "SMM": "Social Media Marketing",
    "SMO": "Social Media Optimization",
    "SN": "Social Network",
    "SROI": "Social Return on Investment",
    "UGC": "User Generated Content",
    "YT": "YouTube",
    "AB": "About",
    "ABT": "About",
    "AFAIK": "As far as I know",
    "AYFKMWTS": "Are you fucking kidding me with this shit?",
    "B4": "Before",
    "BFN": "Bye for now",
    "BGD": "Background",
    "BH": "Blockhead",
    "BR": "Best regards",
    "BTW": "By the way",
    "CD9": "Code 9, parents are around",
    "CHK": "Check",
    "CUL8R": "See you later",
    "DAM": "Don't annoy me",
    "DD": "Dear daughter",
    "DM": "Direct message",
    "DF": "Dear fiancé",
    "DP": "profile pic",
    "DS": "Dear son",
    "DYK": "Did you know, Do you know",
    "EM": "Email",
    "EML": "Email",
    "EMA": "Email address",
    "F2F": "Face to face",
    "FTF": "Face to face",
    "FB": "Facebook",
    "FF": "Follow Friday",
    "FFS": "For Fuck's Sake",
    "FML": "Fuck my life",
    "FOTD": "Find of the day",
    "FTW": "For the win, Fuck the world",
    "FUBAR": "Fucked up beyond all repair",
    "FWIW": "For what it's worth",
    "GMAFB": "Give me a fucking break",
    "GTFOOH": "Get the fuck out of here",
    "GTS": "Guess the song",
    "HAGN": "Have a good night",
    "HAND": "Have a nice day",
    "HOTD": "Headline of the day",
    "HT": "Heard through",
    "HTH": "Hope that helps",
    "IC": "I see",
    "ICYMI": "In case you missed it",
    "IDK": "I don't know",
    "IIRC": "If I remember correctly",
    "IMHO": "In my humble opinion",
    "IRL": "In real life",
    "IWSN": "I want sex now",
    "JK": "Just kidding, joke",
    "JSYK": "Just so you know",
    "JV": "Joint venture",
    "KK": "ok, got it",
    "KYSO": "Knock your socks off",
    "LHH": "Laugh hella hard",
    "LMAO": "Laughing my ass off",
    "LMK": "Let me know",
    "LO": "Little One",
    "LOL": "Laugh out loud",
    "MM": "Music Monday",
    "MIRL": "Meet in real life",
    "MRJN": "Marijuana",
    "NBD": "No big deal",
    "NCT": "Nobody cares, though",
    "NFW": "No fucking way",
    "NJoy": "Enjoy",
    "NSFW": "Not safe for work",
    "NTS": "Note to self",
    "OH": "Overheard",
    "OMG": "Oh my god",
    "OMFG": "Oh my fucking God",
    "OOMF": "One of my friends or followers",
    "ORLY": "Oh, really?",
    "PLMK": "Please let me know",
    "PNP": "Party and Play",
    "QOTD": "quote of the day",
    "RE": "In reply to, in regards to",
    "RLRT": "Real-life re-tweet",
    "RT": "Re-tweet",
    "RTFM": "Read the fucking manual",
    "RTQ": "Read the question",
    "SFW": "Safe for work",
    "SMDH": "Shaking my damn head, SMH, only more so",
    "SMH": "Shaking my head",
    "SNAFU": "Situation normal, all fucked up",
    "SO": "Significant Other",
    "SOB": "Son of a Bitch",
    "SRS": "Serious",
    "STFU": "Shut the fuck up!",
    "STFW": "Search the fucking web!",
    "TFTF": "Thanks for the follow",
    "TFTT": "Thanks for this tweet",
    "TJ": "Tweetjack, or joining a conversation belatedly to contribute to a tangent",
    "TL": "Timeline",
    "TLDR": "Too long, didn't read",
    "TL;DR": "Too long, didn't read",
    "TMB": "Tweet me back",
    "TT": "Trending topic",
    "TY": "Thank you",
    "TYIA": "Thank you in advance",
    "TYT": "Take your time",
    "TYVW": "Thank you very much",
    "W": "With",
    "W/": "With",
    "W/E": "Whatever or weekend",
    "WE": "Whatever or weekend",
    "WTV": "Whatever",
    "YGTR": "You got that right",
    "YKWIM": "You know what I mean",
    "YKYAT": "You know you're addicted to",
    "YMMV": "Your mileage may vary",
    "YOLO": "You only live once",
    "YOYO": "You're on your own",
    "YW": "You're welcome",
    "ZOMG": "OMG to the max",
    "#BrandChat": "private chat about branding",
    "#CMAD": "Community Manager Appreciation Day",
    "#CMGR": "Community Manger topic chat",
    "#FB": "The user is sending this post to Facebook",
    "#FF": "Short way of saying Follow Friday, or a recommendation that others follow the user",
    "#in": "the user is sending this post to LinkedIn",
    "#LI": "This user is sending this post to LinkedIn",
    "#LinkedInChat": "For general use questions and questions about marketing, self-promotion on LinkedIn",
    "#Mmchat": "Marketing and social media chat",
    "#Pinchat": "a chat for maximizing Pinterest use",
    "#SMManners": "Social media manners chat",
    "#SMMeasure": "For discussion of analytics and mesaurement, lead by MarketWire and Syomos",
    "#SMOchat": "Social Media Optimization chat lead by Stanzr",
    "#SocialChat": "Social media chat lead by SocialParle",
    "#SocialMedia": "an all-inclusive chat for subjects big and small in the subject of Social Media"  
}

# convert abbrs to lower case
abbr_lower = dict((k.lower(), v.lower()) for k, v in tweets_abbr.items()) 

def abbr_to_words(doc):
    splits = doc.split()
    new_splits = []
    for split in splits:
        if split in abbr_lower.keys():
            full = abbr_lower[split]
            new_splits.append(full)
        else:
            new_splits.append(split)
    return ' '.join(new_splits)

data['abbr_to_words'] = data['covn_emoji'].apply(abbr_to_words)
data['abbr_to_words'].head(10)
# Out:
# 0    justice world tour 2022 presented by @tmobile ...
# 1    re-tweet @bieberfever: pre-order #justice on v...
# 2    let it go video out right now @djkhaled @21sav...
# 3        justice world tour 2022 presented by @tmobile
# 4
# 5    re-tweet @djkhale tongue sticking out cheeky p...
# 6                                                 fire
# 7    re-tweet @fallontonight: .@justinbieber, jimmy...
# 8          re-tweet @fallontonight: tonight: eyespeach
# 9                   justice listening party starts now
# Name: abbr_to_words, dtype: object

# %% [markdown]
# #### 3. Tokenize words

# %%
from nltk.tokenize import word_tokenize
def doc_to_tokens(doc):
    return word_tokenize(doc)

data['tokenized_docs'] = data['abbr_to_words'].apply(doc_to_tokens)

data['tokenized_docs'].head(10)
# Out:
# 0    [justice, world, tour, 2022, presented, by, @,...
# 1    [re-tweet, @, bieberfever, :, pre-order, #, ju...
# 2    [let, it, go, video, out, right, now, @, djkha...
# 3    [justice, world, tour, 2022, presented, by, @,...
# 4                                                   []
# 5    [re-tweet, @, djkhale, tongue, sticking, out, ...
# 6                                               [fire]
# 7    [re-tweet, @, fallontonight, :, ., @, justinbi...
# 8    [re-tweet, @, fallontonight, :, tonight, :, ey...
# 9             [justice, listening, party, starts, now]
# Name: tokenized_docs, dtype: object

# %% [markdown]
# #### 4. Remove punctuation

# %%
import string

def remove_punct(tokenized_docs):
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    tokenized = []
    for token in tokenized_docs:
        new_token = regex.sub(u'', token)
        if new_token != u'':
            tokenized.append(new_token)
        
    return tokenized

data['tokens_no_punct'] = data['tokenized_docs'].apply(remove_punct)
data['tokens_no_punct'].head(10)
# Out:
# 0    [justice, world, tour, 2022, presented, by, tm...
# 1    [retweet, bieberfever, preorder, justice, on, ...
# 2    [let, it, go, video, out, right, now, djkhaled...
# 3    [justice, world, tour, 2022, presented, by, tm...
# 4                                                   []
# 5    [retweet, djkhale, tongue, sticking, out, chee...
# 6                                               [fire]
# 7    [retweet, fallontonight, justinbieber, jimmy, ...
# 8         [retweet, fallontonight, tonight, eyespeach]
# 9             [justice, listening, party, starts, now]
# Name: tokens_no_punct, dtype: object

# %%
data.head(10)
# Out:
#                     id                                          full_text  \
# 0  1396927212461375489  Justice World Tour 2022 presented by @tmobile ...
# 1  1393239957939146755  RT @bieberfever: Pre-order #JUSTICE on vinyl h...
# 2  1391853886512717828  Let it go video out right now @djkhaled @21sav...
# 3  1390384015358705664  Justice World Tour 2022 presented by @tmobile ...
# 4  1389662980703412233                            https://t.co/I2HzVTGYm8
# 5  1389293667823886338  RT @djkhaled: Video coming #LETITGO @justinbie...
# 6  1389293394728570880                          🔥 https://t.co/yAqVNnn9An
# 7  1387069033485320192  RT @FallonTonight: .@JustinBieber, Jimmy &amp;...
# 8  1386829770336444417  RT @FallonTonight: TONIGHT: 👀🍑 https://t.co/zE...
# 9  1385398169001943046  Justice listening party starts now\nhttps://t....
#
#     screen_name           user  \
# 0  justinbieber  Justin Bieber
# 1  justinbieber  Justin Bieber
# 2  justinbieber  Justin Bieber
# ...

# %% [markdown]
# #### 5. Remove stop words

# %%
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))

def remove_stopwords(tokenized_docs):
    
    no_stopwords = []
    for token in tokenized_docs:
        if token not in STOPWORDS:
            no_stopwords.append(token)
        
    return no_stopwords

data['no_stopwords'] = data['tokens_no_punct'].apply(remove_stopwords)
data['no_stopwords'].head(10)
# Out:
# 0    [justice, world, tour, 2022, presented, tmobil...
# 1     [retweet, bieberfever, preorder, justice, vinyl]
# 2    [let, go, video, right, djkhaled, 21savage, vi...
# 3     [justice, world, tour, 2022, presented, tmobile]
# 4                                                   []
# 5    [retweet, djkhale, tongue, sticking, cheeky, p...
# 6                                               [fire]
# 7    [retweet, fallontonight, justinbieber, jimmy, ...
# 8         [retweet, fallontonight, tonight, eyespeach]
# 9                  [justice, listening, party, starts]
# Name: no_stopwords, dtype: object

# %% [markdown]
# #### 5. Spelling correction

# %%
# this step takes some tome to process
from textblob import TextBlob

def spelling(doc):
    new_doc = []
    for token in doc:
        new_token = str(TextBlob(token).correct())
        new_doc.append(new_token)
    return new_doc

data['spelling'] = data['no_stopwords'].apply(spelling)

# %%
data['spelling'].head(10)
# Out:
# 0    [justice, world, tour, 2022, presented, mobile...
# 1     [between, bieberfever, recorder, justice, final]
# 2    [let, go, video, right, djkhaled, savage, vide...
# 3      [justice, world, tour, 2022, presented, mobile]
# 4                                                   []
# 5    [between, djkhale, tongue, sticking, cheeks, p...
# 6                                               [fire]
# 7    [between, fallontonight, justinbieber, jimmy, ...
# 8         [between, fallontonight, tonight, eyespeach]
# 9                  [justice, listening, party, starts]
# Name: spelling, dtype: object
